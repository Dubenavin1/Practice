# %%
print("hii")
# Out:
# hii

# %%
print("hello")
# Out:
# hello

# %%
print("I AM NAVEEN DUBEY")
# Out:
# I AM NAVEEN DUBEY

# %%
print("THIS IS BASIC")
# Out:
# THIS IS BASIC

# %%
print("I AM FELLING GOOD TO DO CODING")
# Out:
# I AM FELLING GOOD TO DO CODING

# %% [markdown]
# ONE CONDITION IS THIS

# %%
print("""hii""")
# Out:
# hii

# %%
print(""""HELLO THIS IS 
ANOTHER METHOD""")
# Out:
# "HELLO THIS IS
# ANOTHER METHOD

# %%
print("""This article is about the Republic of India. For other uses, see India (disambiguation).
Republic of India
Bhārat Gaṇarājya
(see other local names)
Horizontal tricolour flag bearing, from top to bottom, deep saffron, white, and green horizontal bands. In the centre of the white band is a navy-blue wheel with 24 spokes.
Flag
Three lions facing left, right, and toward viewer, atop a frieze containing a galloping horse, a 24-spoke wheel, and an elephant. Underneath is a motto: "सत्यमेव जयते".
State emblem
Motto: "Satyameva Jayate" (Sanskrit)
"Truth Alone Triumphs"[1]
Anthem: "Jana Gana Mana"[2][3]
"Thou Art the Ruler of the Minds of All People"[4][2]
1:04
National song
"Vande Mataram" (Sanskrit)
"I Bow to Thee, Mother"[a][1][2]
Image of a globe centred on India, with India highlighted.
Territory controlled by India shown in dark green; territory claimed but not controlled shown in light green
Capital	New Delhi
28°36′50″N 77°12′30″E
Largest city	
Mumbai (city proper)
Delhi (metropolitan area)
Official languages	
HindiEnglish[b][8]
Recognised national languages	None[9][10][11]
Recognised regional languages	
State level and Eighth Schedule[12]
Native languages	447 languages[c]
Religion (2011)	
79.8% Hinduism
14.2% Islam
2.3% Christianity
1.7% Sikhism
0.7% Buddhism
0.4% Jainism
0.23% Unaffiliated
0.65% Others[15]
Demonym(s)	Indian
Government	Federal parliamentary constitutional republic
• President
Droupadi Murmu
• Vice President
Jagdeep Dhankhar
• Prime Minister
Narendra Modi
• Chief Justice
Uday Umesh Lalit
• Lok Sabha Speaker
Om Birla
Legislature	Parliament
• Upper house
Rajya Sabha
• Lower house
Lok Sabha
Independence from the United Kingdom
• Dominion
15 August 1947
• Republic
26 January 1950
Area
• Total
3,287,263[2] km2 (1,269,219 sq mi)[d] (7th)
• Water (%)
9.6
Population
• 2022 estimate
1,375,586,000[17] (2nd)
• 2011 census
1,210,854,977[18][19] (2nd)
• Density
417.3/km2 (1,080.8/sq mi) (19th)
GDP (PPP)	2022 estimate
• Total
Increase $11.745 trillion[20] (3rd)
• Per capita
Increase $8,358[20] (128th)
GDP (nominal)	2022 estimate
• Total
Increase $3.535 trillion[20] (5th)
• Per capita
Increase $2,515[20] (142th)
Gini (2011)	35.7[21][22]
medium · 98th
HDI (2021)	Decrease 0.633[23]
medium · 132nd
Currency	Indian rupee (₹) (INR)
Time zone	UTC+05:30 (IST)
DST is not observed
Date format	
dd-mm-yyyy[e]
Driving side	left[24]
Calling code	+91
ISO 3166 code	IN
Internet TLD	.in (others)
India, officially the Republic of India (Hindi: Bhārat Gaṇarājya),[25] is a country in South Asia. It is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[f] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia. The nation's capital city is New Delhi.""")
# Out:
# This article is about the Republic of India. For other uses, see India (disambiguation).
# Republic of India
# Bhārat Gaṇarājya
# (see other local names)
# Horizontal tricolour flag bearing, from top to bottom, deep saffron, white, and green horizontal bands. In the centre of the white band is a navy-blue wheel with 24 spokes.
# Flag
# Three lions facing left, right, and toward viewer, atop a frieze containing a galloping horse, a 24-spoke wheel, and an elephant. Underneath is a motto: "सत्यमेव जयते".
# State emblem
# Motto: "Satyameva Jayate" (Sanskrit)
# "Truth Alone Triumphs"[1]
# Anthem: "Jana Gana Mana"[2][3]
# "Thou Art the Ruler of the Minds of All People"[4][2]
# 1:04
# National song
# "Vande Mataram" (Sanskrit)
# "I Bow to Thee, Mother"[a][1][2]
# Image of a globe centred on India, with India highlighted.
# Territory controlled by India shown in dark green; territory claimed but not controlled shown in light green
# Capital	New Delhi
# 28°36′50″N 77°12′30″E
# Largest city
# ...

# %%
print('HII I AM "NAVEEN"')
# Out:
# HII I AM "NAVEEN"

# %% [markdown]
# # this is also fine THis is exeptional cases of print
# # we have to use single cod outside

# %%
print('HII I  AM "NAVEEN"')
# Out:
# HII I  AM "NAVEEN"

# %% [markdown]
# # IT IS ALSO FINE IF I USE SINGLE CODE INSIDE

# %%
6465+655 #Quetient of two number
# Out:
# 7120

# %%
479-455
# Out:
# 24

# %%
988*4  # multiply of two numbers
# Out:
# 3952

# %% [markdown]
# # POWER IN NUMBERS
#
#
# > LIKE

# %%
789**2 # power of 789
# Out:
# 622521

# %%
989***7 #power of 989
# Out:
#   File "<ipython-input-25-7f19ff8c7e3a>", line 1
#     989***7 #power of 989
#          ^
# SyntaxError: invalid syntax

# %%
print("hii to divya")
# Out:
# hii to divya

# %%
989**9 #power of 989
# Out:
# 905246020621685512715981309

# %%
print("""hey divya
whatsapp""")
# Out:
# hey divya
# whatsapp

# %%
4555%4
# Out:
# 3

# %%
22%2
# Out:
# 0

# %%
print(9998+222)
print("result")
# Out:
# 10220
# result

# %%
9998+5555
print("result")
# Out:
# result

# %% [markdown]
# # IF WE USE PRINT RESULT THEN  ARE GOING ON

# %% [markdown]
# # VARIABLE IN PYTHON
# ## VARIABLE IN PYTHON
# ### New VARIABLE IN PYTHON

# %%
x=10
print(x)
# Out:
# 10

# %%
y=20
print(y)
# Out:
# 20

# %%
print(x+y)
# Out:
# 30

# %% [markdown]
# # IT IS IMPORTANT

# %%
x=90
print(x)
# Out:
# 90

# %%
y=100
print(y)
# Out:
# 100

# %%
print(x-y)
# Out:
# -10

# %%
print(x*y)
# Out:
# 9000

# %%
print(x/y)
# Out:
# 0.9

# %%
ten=10

# %%
twenty=20

# %%
(ten+twenty)
# Out:
# 30

# %%
 ten=10
 ten number=10
 ten% number=10
# Out:
#   File "<ipython-input-61-8554e9139890>", line 2
#     ten number=10
#              ^
# SyntaxError: invalid syntax

# %%
_ten=10

# %%
ten_
number=10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-d1be21bea6bc> in <module>
# ----> 1 ten_
#       2 number=10
#
# NameError: name 'ten_' is not defined

# %%
Ten_number=10

# %%
_=10    # dummy Variable

# %% [markdown]
# DATA

# %% [markdown]
# FUNDAMENTAL DATA TYPES
#
# ```

# %%
a=9
type(a)
# Out:
# int

# %%
B=156
type(B)
# Out:
# int

# %% [markdown]
# FLOAT -IT IS THAT VALUE WHICH IS IN DECIMAL IS CALLED FLOAT VALUE

# %%
x=22.7
type(x)
# Out:
# float

# %%
pi=22/7
pi
# Out:
# 3.142857142857143

# %%
type(pi)
# Out:
# float

# %% [markdown]
# COMPLEX NUMBER

# %%
a=6+19j
(a)
# Out:
# (6+19j)

# %%
type(a)
# Out:
# complex

# %%
a.imag
# Out:
# 19.0

# %% [markdown]
# DYNAMIC TYPING

# %%
a=22.33
print(type(a))
a=99
print(type(a))
a=33+3j
print(type(a))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
print(int)
# Out:
# <class 'int'>

# %%
print(a)
# Out:
# (33+3j)

# %%
a=2
(type(a))
a=99
(type(a))
a=33+3j
(type(a))
# Out:
# complex

# %%
a="naveen"
type(a)
# Out:
# str

# %%
print(a)
# Out:
# naveen

# %%
print("""hii""")
# Out:
# hii

# %%
print("""HELLO THIS IS (NAVEEN)""")
# Out:
# HELLO THIS IS (NAVEEN)

# %%
242+222
# Out:
# 464

# %%
298/8
# Out:
# 37.25

# %%
print(9888*8)
print("result")
# Out:
# 79104
# result

# %%
a=55
type(a)
# Out:
# int

# %%
a=55.5
type(a)
# Out:
# float

# %%
a=22
print (type(a))
a=220.7
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a="NAVEEN"
type(a)
# Out:
# str

# %%
a="""Naveen"""
type(a)
# Out:
# str

# %%
"Day"+"1"
# Out:
# 'Day1'

# %%
"2525"+"46445"
# Out:
# '252546445'

# %%
"Naveen"+"Dubey"
# Out:
# 'NaveenDubey'

# %%
language="python"
print("Hii welcome to the "+language+" language")
# Out:
# Hii welcome to the python language

# %% [markdown]
# # IT IS USED RARELY

# %%
LANGUAGE="JAVA Subscript"
print(f "hi welcome to the{} LANGUAGE")
# Out:
#   File "<ipython-input-31-95b7263a6f8f>", line 2
#     print(f "hi welcome to the{} LANGUAGE")
#                                          ^
# SyntaxError: invalid syntax

# %%
language="java script"
print(f"hii welcome to {language} language")
# Out:
# hii welcome to java script language

# %% [markdown]
# # THIS IS USED ACTUALY

# %% [markdown]
# OLD WAY OF CODING OF PYTHON

# %%
languge = "python"
print("hi welcome to {} language".format(language))
# Out:
# hi welcome to java script language

# %%
x=85
type(x)
# Out:
# int

# %%
x=98
y=85
(x+y)
# Out:
# 183

# %%
989+9889
# Out:
# 10878

# %%
print("\U0001F600")
# Out:
# 😀

# %%
print("\U0001F1022")
# Out:
# 🄂2

# %%
make="Happy"
name="Naveen"
behaviour="Good"
print(f"hii My Name Is {name} i make everyone {make} I have Good {behaviour}")
# Out:
# hii My Name Is Naveen i make everyone Happy I have Good Good

# %% [markdown]
# # OLD WAY

# %%
num="first"
language="python"
print("hii today is{}class of{}language".format(num , language))
# Out:
# hii today isfirstclass ofpythonlanguage

# %% [markdown]
# ## THESE METHOD ALSO GOOD

# %%
num="first"
language="python"
print("hii today is"+num+"class of"+language+"language")
# Out:
# hii today isfirstclass ofpythonlanguage

# %%
print("\U0001F600")
print("\U0001F618")
print("\U0001F917")
print("\U0001F62A")
# Out:
# 😀
# 😘
# 🤗
# 😪

# %%
print("\U0001F870")
# Out:
# 🡰

# %%
print("\U0001F812")
# Out:
# 🠒

# %%
print("\U0001F300")
# Out:
# 🌀

# %%
print("\U0001F700")
# Out:
# 🜀

# %%
a=22
b=45
c=(a*b)
print(f"{c}");
# Out:
# 990

# %%
a=7
b=5
c=a+b
print(f"the sum of a+b={c}")
# Out:
# the sum of a+b=12

# %%
a=7
b=5
c=a+b
print(f"sum of a:{a} and b:{b} is ={c}")
# Out:
# sum of a:7 and b:5 is =12

# %% [markdown]
# ### BOOLEAN DATA TYPE

# %%
A=True
B=False
print(type(A))
print(type(B))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
a=i am good man
b=what i do
print(type(a))

# %%
A=True
B=False
print(type(A))
# Out:
# <class 'bool'>

# %%
raining=true
umbrela=true
can i go callage
# Out:
#   File "<ipython-input-9-3d2542247c52>", line 3
#     can i go callage
#         ^
# SyntaxError: invalid syntax

# %%
a=True
b=False
print(a+b)
print(type(a))
# Out:
# 1
# <class 'bool'>

# %%
"""Naveen"""
# Out:
# 'Naveen'

# %%
x=("22")
y=("22")
print("sum of (x+y"))
# Out:
#   File "<ipython-input-21-dc0b78212dbb>", line 3
#     print("sum of (x+y"))
#                         ^
# SyntaxError: invalid syntax

# %%
class start at=6pm
you came at=7pm
you came at<class start at
# Out:
#   File "<ipython-input-26-68bbbc886209>", line 1
#     class start at=6pm
#                  ^
# SyntaxError: invalid syntax

# %%
Class 
Start at="1500";
You come at="1600";
You come at < Class Start at;
# Out:
#   File "<ipython-input-18-fa368be0cb6d>", line 2
#     Start at="1500";
#            ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-17-6a4154195b7a>", line 1
#     class_start_at = 4pm
#                        ^
# SyntaxError: invalid syntax

# %%
class_start_at=1300
you_come_at=1400
you_come_at<class_start_at
# Out:
# False

# %%
raining=true
I have umbrella=true
# Out:
#   File "<ipython-input-21-68eb691c46bb>", line 2
#     I have umbrella=true
#          ^
# SyntaxError: invalid syntax

# %%
a=2
b=2
c=2
Result=a+b+c
print(f"sum of {Result}")
# Out:
# sum of 6

# %%
a=773
b=888
c=525
RESULT=(a+b+c)
print(f"sum of result {RESULT}")
# Out:
# sum of result 2186

# %%
# Out:
#   File "<ipython-input-4-838934271bb5>", line 1
#     (U\0001F602)
#                 ^
# SyntaxError: unexpected character after line continuation character
